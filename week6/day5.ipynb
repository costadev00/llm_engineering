# %% [markdown]
# # The Product Pricer Continued
#
# A model that can estimate how much something costs, from its description.
#
# ## AT LAST - it's time for Fine Tuning!
#
# After all this data preparation, and old school machine learning, we've finally arrived at the moment you've been waiting for. Fine-tuning a model.

# %%
# imports

import os
import re
import math
import json
import random
from dotenv import load_dotenv
from huggingface_hub import login
import matplotlib.pyplot as plt
import numpy as np
import pickle
from collections import Counter
from openai import OpenAI
from anthropic import Anthropic

# %%
# environment

load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['ANTHROPIC_API_KEY'] = os.getenv('ANTHROPIC_API_KEY', 'your-key-if-not-using-env')
os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN', 'your-key-if-not-using-env')

# %%
# Log in to HuggingFace

hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# moved our Tester into a separate package
# call it with Tester.test(function_name, test_dataset)

from items import Item
from testing import Tester

# %%
openai = OpenAI()

# %%
# %matplotlib inline

# %%
# Let's avoid curating all our data again! Load in the pickle files:

with open('train.pkl', 'rb') as file:
    train = pickle.load(file)

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
# OpenAI recommends fine-tuning with populations of 50-100 examples
# But as our examples are very small, I'm suggesting we go with 200 examples (and 1 epoch)

fine_tune_train = train[500:750]
fine_tune_validation = train[750:800]

# %%
# print(train[399000].prompt)
print(len(train))
# Out:
# 400000

# %% [markdown]
# # Step 1
#
# Prepare our data for fine-tuning in JSONL (JSON Lines) format and upload to OpenAI

# %%
# First let's work on a good prompt for a Frontier model
# Notice that I'm removing the " to the nearest dollar"
# When we train our own models, we'll need to make the problem as easy as possible, 
# but a Frontier model needs no such simplification.

def messages_for(item):
    system_message = "You estimate prices of items. Reply only with the price, no explanation"
    user_prompt = item.test_prompt().replace(" to the nearest dollar","").replace("\n\nPrice is $","")
    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_prompt},
        {"role": "assistant", "content": f"Price is ${item.price:.2f}"}
    ]

# %%
messages_for(train[0])
# Out:
# [{'role': 'system',
#   'content': 'You estimate prices of items. Reply only with the price, no explanation'},
#  {'role': 'user',
#   'content': 'How much does this cost?\n\nDelphi FG0166 Fuel Pump Module\nDelphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7'},
#  {'role': 'assistant', 'content': 'Price is $226.95'}]

# %%
# Convert the items into a list of json objects - a "jsonl" string
# Each row represents a message in the form:
# {"messages" : [{"role": "system", "content": "You estimate prices...


def make_jsonl(items):
    result = ""
    for item in items:
        messages = messages_for(item)
        messages_str = json.dumps(messages)
        result += '{"messages": ' + messages_str +'}\n'
    return result.strip()

# %%
print(make_jsonl(train[:3]))
# Out:
# {"messages": [{"role": "system", "content": "You estimate prices of items. Reply only with the price, no explanation"}, {"role": "user", "content": "How much does this cost?\n\nDelphi FG0166 Fuel Pump Module\nDelphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7"}, {"role": "assistant", "content": "Price is $226.95"}]}
# {"messages": [{"role": "system", "content": "You estimate prices of items. Reply only with the price, no explanation"}, {"role": "user", "content": "How much does this cost?\n\nPower Stop Rear Z36 Truck and Tow Brake Kit with Calipers\nThe Power Stop Z36 Truck & Tow Performance brake kit provides the superior stopping power demanded by those who tow boats, haul loads, tackle mountains, lift trucks, and play in the harshest conditions. The brake rotors are drilled to keep temperatures down during extreme braking and slotted to sweep away any debris for constant pad contact. Combined with our Z36 Carbon-Fiber Ceramic performance friction formulation, you can confidently push your rig to the limit and look good doing it with red powder brake calipers. Components are engineered to handle the stress of towing, hauling, mountainous driving, and lifted trucks. Dust-free braking performance. Z36 Carbon-Fiber Ceramic formula provides the extreme braking performance demanded by your truck or 4x"}, {"role": "assistant", "content": "Price is $506.98"}]}
# {"messages": [{"role": "system", "content": "You estimate prices of items. Reply only with the price, no explanation"}, {"role": "user", "content": "How much does this cost?\n\nABBA 36 Gas Cooktop with 5 Sealed Burners - Tempered Glass Surface with SABAF Burners, Natural Gas Stove for Countertop, Home Improvement Essentials, Easy to Clean, 36 x 4.1 x 20.5\ncooktop Gas powered with 4 fast burners and 1 ultra-fast center burner Tempered glass surface with removable grid for easy cleaning Lightweight for easy installation. Installation Manual Included Counter cutout Dimensions 19 3/8 x 34 1/2 (see diagram) Insured shipping for your satisfaction and peace of mind Brand Name ABBA EST. 1956, Weight 30 pounds, Dimensions 20.5\\ D x 36\\ W x 4.1\\ H, Installation Type Count"}, {"role": "assistant", "content": "Price is $405.00"}]}

# %%
# Convert the items into jsonl and write them to a file

def write_jsonl(items, filename):
    with open(filename, "w") as f:
        jsonl = make_jsonl(items)
        f.write(jsonl)

# %%
write_jsonl(fine_tune_train, "fine_tune_train.jsonl")

# %%
write_jsonl(fine_tune_validation, "fine_tune_validation.jsonl")

# %%
with open("fine_tune_train.jsonl", "rb") as f:
    train_file = openai.files.create(file=f, purpose="fine-tune")

# %%
train_file
# Out:
# FileObject(id='file-AvZYTF7Nm4r7qfxmjgbgFZ', bytes=234841, created_at=1762296560, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
with open("fine_tune_validation.jsonl", "rb") as f:
    validation_file = openai.files.create(file=f, purpose="fine-tune")

# %%
# validation_file
openai.files.list()
# Out:
# SyncCursorPage[FileObject](data=[FileObject(id='file-WFVH9HsrxHd3YhnVxPByEQ', bytes=46364, created_at=1762296564, filename='fine_tune_validation.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-AvZYTF7Nm4r7qfxmjgbgFZ', bytes=234841, created_at=1762296560, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-S5BLG1xRHLXpcW3mjvKW3x', bytes=47351, created_at=1762294984, filename='fine_tune_validation.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-Bjyyg9k3EcWuNMwbnnd9ZR', bytes=187488, created_at=1762294980, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-HjbdpYE1CCKKjA6roeJ41a', bytes=47108, created_at=1762271167, filename='fine_tune_validation.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-UBp9ATDKBQRudCz8cWYg5w', bytes=470870, created_at=1762271160, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-3jYVVdQeDJU3g9yi2HXG1N', bytes=470870, created_at=1762271111, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-HdY6iRkWFFCv28ATuR92Vm', bytes=5384, created_at=1762269116, filename='step_metrics.csv', object='file', purpose='fine-tune-results', status='processed', expires_at=None, status_details=None), FileObject(id='file-7BVjJiSx14anAkJheAo723', bytes=47085, created_at=1762266399, filename='fine_tune_validation.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None), FileObject(id='file-RTmUbwr5YP3WJwUu2Xxb9o', bytes=188742, created_at=1762266380, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)], has_more=False, object='list', first_id='file-WFVH9HsrxHd3YhnVxPByEQ', last_id='file-RTmUbwr5YP3WJwUu2Xxb9o')

# %% [markdown]
# # Step 2
#
# I love Weights and Biases - a beautiful, free platform for monitoring training runs.
# Weights and Biases is integrated with OpenAI for fine-tuning.
#
# First set up your weights & biases free account at:
#
# https://wandb.ai
#
# From the Avatar >> Settings menu, near the bottom, you can create an API key.
#
# Then visit the OpenAI dashboard at:
#
# https://platform.openai.com/account/organization
#
# In the integrations section, you can add your Weights & Biases key.
#
# ## And now time to Fine-tune!

# %%
wandb_integration = {"type": "wandb", "wandb": {"project": "gpt-pricer"}}

# %%
train_file.id
# Out:
# 'file-AvZYTF7Nm4r7qfxmjgbgFZ'

# %%
openai.fine_tuning.jobs.create(
    training_file=train_file.id,
    validation_file=validation_file.id,
    model="ft:gpt-4o-2024-08-06:matheus-costa:pricer:CYCmzLTt",
    seed=42,
    hyperparameters={"n_epochs": 1},
    integrations = [wandb_integration],
    suffix="pricer-new-round"
)
# Out:
# FineTuningJob(id='ftjob-rtImq91Sj4CAZRoWqegl69sy', created_at=1762296575, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=1), model='ft:gpt-4o-2024-08-06:matheus-costa:pricer:CYCmzLTt', object='fine_tuning.job', organization_id='org-fmgrsK0Or64kvf0qRpWT3wIX', result_files=[], seed=42, status='validating_files', trained_tokens=None, training_file='file-AvZYTF7Nm4r7qfxmjgbgFZ', validation_file='file-WFVH9HsrxHd3YhnVxPByEQ', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-rtImq91Sj4CAZRoWqegl69sy'))], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=1))), user_provided_suffix='pricer-new-round', usage_metrics=None, shared_with_openai=False, eval_id=None)

# %%
openai.fine_tuning.jobs.list()
# Out:
# SyncCursorPage[FineTuningJob](data=[FineTuningJob(id='ftjob-rtImq91Sj4CAZRoWqegl69sy', created_at=1762296575, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-4o-2024-08-06:matheus-costa:pricer-new-round:CYKWgvK0', finished_at=1762298089, hyperparameters=Hyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1), model='ft:gpt-4o-2024-08-06:matheus-costa:pricer:CYCmzLTt', object='fine_tuning.job', organization_id='org-fmgrsK0Or64kvf0qRpWT3wIX', result_files=['file-5AWxhNTrRdAGcVGL6vedCk'], seed=42, status='succeeded', trained_tokens=49032, training_file='file-AvZYTF7Nm4r7qfxmjgbgFZ', validation_file='file-WFVH9HsrxHd3YhnVxPByEQ', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-rtImq91Sj4CAZRoWqegl69sy'))], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1))), user_provided_suffix='pricer-new-round', usage_metrics=None, shared_with_openai=False, eval_id=None), FineTuningJob(id='ftjob-efGK3loR9oMm47eVKkvMYQiv', created_at=1762294999, error=Error(code='exceeded_quota', message='Creating this fine-tuning job would exceed your hard limit, please check your plan and billing details.                     Cost of job ftjob-efGK3loR9oMm47eVKkvMYQiv: USD 0.98. Quota remaining for your project proj_EzV5cwoKqNVq2kCI66lVLVEk: USD 0.87.', param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1), model='ft:gpt-4o-2024-08-06:matheus-costa:pricer:CYCmzLTt', object='fine_tuning.job', organization_id='org-fmgrsK0Or64kvf0qRpWT3wIX', result_files=[], seed=42, status='failed', trained_tokens=None, training_file='file-Bjyyg9k3EcWuNMwbnnd9ZR', validation_file='file-S5BLG1xRHLXpcW3mjvKW3x', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-efGK3loR9oMm47eVKkvMYQiv'))], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1))), user_provided_suffix='pricer-new-round', usage_metrics=None, shared_with_openai=False, eval_id=None), FineTuningJob(id='ftjob-OL6lozomnj7QxWqRRfhYk1IW', created_at=1762271210, error=Error(code='exceeded_quota', message='Creating this fine-tuning job would exceed your hard limit, please check your plan and billing details.                     Cost of job ftjob-OL6lozomnj7QxWqRRfhYk1IW: USD 2.45. Quota remaining for your project proj_EzV5cwoKqNVq2kCI66lVLVEk: USD 0.87.', param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1), model='gpt-4o-2024-08-06', object='fine_tuning.job', organization_id='org-fmgrsK0Or64kvf0qRpWT3wIX', result_files=[], seed=42, status='failed', trained_tokens=None, training_file='file-UBp9ATDKBQRudCz8cWYg5w', validation_file='file-HjbdpYE1CCKKjA6roeJ41a', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-OL6lozomnj7QxWqRRfhYk1IW'))], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1))), user_provided_suffix='pricer-500', usage_metrics=None, shared_with_openai=False, eval_id=None), FineTuningJob(id='ftjob-gAkJSeJcOGYyyzfhsgqxy7kz', created_at=1762267447, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-4o-2 ...

# %%
job_id = openai.fine_tuning.jobs.list(limit=1).data[0].id

# %%
job_id
# Out:
# 'ftjob-rtImq91Sj4CAZRoWqegl69sy'

# %%
openai.fine_tuning.jobs.retrieve(job_id)
# Out:
# FineTuningJob(id='ftjob-rtImq91Sj4CAZRoWqegl69sy', created_at=1762296575, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-4o-2024-08-06:matheus-costa:pricer-new-round:CYKWgvK0', finished_at=1762298089, hyperparameters=Hyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1), model='ft:gpt-4o-2024-08-06:matheus-costa:pricer:CYCmzLTt', object='fine_tuning.job', organization_id='org-fmgrsK0Or64kvf0qRpWT3wIX', result_files=['file-5AWxhNTrRdAGcVGL6vedCk'], seed=42, status='succeeded', trained_tokens=49032, training_file='file-AvZYTF7Nm4r7qfxmjgbgFZ', validation_file='file-WFVH9HsrxHd3YhnVxPByEQ', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-rtImq91Sj4CAZRoWqegl69sy'))], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=1))), user_provided_suffix='pricer-new-round', usage_metrics=None, shared_with_openai=False, eval_id=None)

# %%
openai.fine_tuning.jobs.list_events(fine_tuning_job_id=job_id, limit=10).data
# Out:
# [FineTuningJobEvent(id='ftevent-Zubez03fSMyGLlV70mkJKhX7', created_at=1762298866, level='info', message='The job has successfully completed', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-Y9ocQW6MRz1koWqe6lJiT8JQ', created_at=1762298858, level='info', message='Usage policy evaluations completed, model is now enabled for sampling', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-hGQQvpyssubKfOfZz9jGGcqO', created_at=1762298858, level='info', message='Moderation checks for snapshot ft:gpt-4o-2024-08-06:matheus-costa:pricer-new-round:CYKWgvK0 passed.', object='fine_tuning.job.event', data={'blocked': False, 'results': [{'flagged': False, 'category': 'harassment/threatening', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'sexual', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'sexual/minors', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'propaganda', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'hate', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'hate/threatening', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'illicit', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'violence', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'advice', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'self-harm/intent', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'self-harm/instructions', 'enforcement': 'non_blocking'}, {'flagged': False, 'category': 'sensitive', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'highly-sensitive', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'biological threats', 'enforcement': 'blocking'}, {'flagged': False, 'category': 'cyber security threats', 'enforcement': 'blocking'}], 'finetuned_model_checkpoint_id': 'ft:gpt-4o-2024-08-06:matheus-costa:pricer-new-round:CYKWgvK0'}, type='moderation_checks'),
#  FineTuningJobEvent(id='ftevent-p93TZeJRZEWCniRDvHglcB6B', created_at=1762298091, level='info', message='Evaluating model against our usage policies', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-4qGSl6fzYDRbrZZHXb7ZzIod', created_at=1762298091, level='info', message='New fine-tuned model created', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-scrH1S8C7S0NCcFjYxI0SOtS', created_at=1762298069, level='info', message='Step 250/250: training loss=0.55, validation loss=1.20, full validation loss=1.05', object='fine_tuning.job.event', data={'step': 250, 'train_loss': 0.5453934669494629, 'valid_loss': 1.200831651687622, 'total_steps': 250, 'full_valid_loss': 1.051142258644104, 'train_mean_token_accuracy': 0.875, 'valid_mean_token_accuracy': 0.75, 'full_valid_mean_token_accuracy': 0.8025}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-u2UHwjB7pcR4cbE4SlQF3GYL', created_at=1762298053, level='info', message='Step 249/250: training loss=1.35', object='fine_tuning.job.event', data={'step': 249, 'train_loss': 1.3481123447418213, 'total_steps': 250, 'train_mean_token_accuracy': 0.75}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-eKMm45K7PUH7IAf5LqEjyiPk', created_at=1762298052, level='info', message='Step 248/250: training loss=1.24', object='fine_tuning.job.event', data={'step': 248, 'train_loss': 1.2399823665618896, 'total_steps': 250, 'train_mean_token_accuracy': 0.75}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-PzeqM87aDHbbiZHnydZ9Mdve', created_at=1762298045, level='info', message='Step 247/250: training loss=0.68', object='fine_tuning.job.event', data={'step': 247, 'train_loss': 0.6790046691894531, 'total_steps': 250, 'train_mean_token_accuracy': 0.875}, type='metrics'),
#  FineTuningJobEvent(id='ftevent-hztZYxdFAe8gQE113oc9J5F2', created_at=1762298045, level='info', message='Step 246/250: training loss=0.95', object='fine_tuning.job.event', data={'step': 246, 'train_loss': 0.9531898498535156, 'total_steps': 250, 'train_mean_token_accuracy': 0.75}, type='metrics')]

# %% [markdown]
# # Step 3
#
# Test our fine tuned model

# %%
fine_tuned_model_name = openai.fine_tuning.jobs.retrieve(job_id).fine_tuned_model

# %%
print(fine_tuned_model_name)
# Out:
# ft:gpt-4o-2024-08-06:matheus-costa:pricer-new-round:CYKWgvK0

# %%
# The prompt

def messages_for(item):
    system_message = "You estimate prices of items. Reply only with the price, no explanation"
    user_prompt = item.test_prompt().replace(" to the nearest dollar","").replace("\n\nPrice is $","")
    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_prompt},
        {"role": "assistant", "content": "Price is $"}
    ]

# %%
# Try this out

messages_for(test[0])
# Out:
# [{'role': 'system',
#   'content': 'You estimate prices of items. Reply only with the price, no explanation'},
#  {'role': 'user',
#   'content': "How much does this cost?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K"},
#  {'role': 'assistant', 'content': 'Price is $'}]

# %%
# A utility function to extract the price from a string

def get_price(s):
    s = s.replace('$','').replace(',','')
    match = re.search(r"[-+]?\d*\.\d+|\d+", s)
    return float(match.group()) if match else 0

# %%
get_price("The price is roughly $99.99 because blah blah")
# Out:
# 99.99

# %%
# The function for gpt-4o-mini

def gpt_fine_tuned(item):
    response = openai.chat.completions.create(
        model=fine_tuned_model_name, 
        messages=messages_for(item),
        seed=42,
        max_tokens=7
    )
    reply = response.choices[0].message.content
    return get_price(reply)

# %%
print(test[0].price)
print(gpt_fine_tuned(test[0]))
# Out:
# 374.41
# 268.41

# %%
print(test[0].test_prompt())
# Out:
# How much does this cost to the nearest dollar?
#
# OEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW
# As one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K
#
# Price is $

# %%
Tester.test(gpt_fine_tuned, test)
# Out:
# 1: Guess: $268.41 Truth: $374.41 Error: $106.00 SLE: 0.11 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $156.66 Truth: $225.11 Error: $68.45 SLE: 0.13 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $101.57 Truth: $61.68 Error: $39.89 SLE: 0.24 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $419.00 Truth: $599.99 Error: $180.99 SLE: 0.13 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $10.99 Truth: $16.99 Error: $6.00 SLE: 0.16 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $32.99 Truth: $31.99 Error: $1.00 SLE: 0.00 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $101.00 Truth: $101.79 Error: $0.79 SLE: 0.00 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $367.99 Truth: $289.00 Error: $78.99 SLE: 0.06 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $599.99 Truth: $635.86 Error: $35.87 SLE: 0.00 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# 10: Guess: $66.47 Truth: $65.99 Error: $0.48 SLE: 0.00 Item: HOLDWILL 6 Pack LED Shop Light, 4FT 24W ...
# 11: Guess: $194.99 Truth: $254.21 Error: $59.22 SLE: 0.07 Item: Viking Horns V103C/1005ATK 3 Gallon Air ...
# 12: Guess: $315.66 Truth: $412.99 Error: $97.33 SLE: 0.07 Item: CURT 70110 Custom Tow Bar Base Plate Bra...
# 13: Guess: $69.99 Truth: $205.50 Error: $135.51 SLE: 1.14 Item: 10-Pack Solar HAMMERED BRONZE Finish Pos...
# 14: Guess: $276.99 Truth: $248.23 Error: $28.76 SLE: 0.01 Item: COSTWAY Electric Tumble Dryer, Sliver
